# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import openpyxl
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

# %%
import pandas as pd
import warnings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# ===============================
# 1. Cargar datos (igual)
# ===============================
def cargar_datos(ruta):
    df = pd.read_excel(ruta)
    return df


# ===============================
# 2. Validar columnas de forma flexible
# ===============================
def obtener_columnas_validas(df):
    columnas_esperadas = [
        'inasistencias',
        'promedio',
        'participacion',
        'apoyo_familiar'
    ]

    columnas_disponibles = []

    for col in columnas_esperadas:
        if col in df.columns:
            columnas_disponibles.append(col)
        else:
            warnings.warn(f"Advertencia: No se encontró la columna '{col}'. Se omitirá.")

    if len(columnas_disponibles) < 2:
        raise ValueError("Error crítico: Muy pocas variables para entrenar el modelo.")

    return columnas_disponibles


# ===============================
# 3. Limpieza automática de tipos y nulos
# ===============================
def limpiar_datos(df, columnas):
    for col in columnas:
        df[col] = pd.to_numeric(df[col], errors='coerce')

    nulos = df[columnas].isnull().sum().sum()
    if nulos > 0:
        warnings.warn(f"Advertencia: Se encontraron {nulos} valores nulos. Se reemplazarán por la media.")
        df[columnas] = df[columnas].fillna(df[columnas].mean())

    return df


# ===============================
# 4. Definir X e y de forma flexible
# ===============================
def definir_variables(df, columnas):
    if 'deserto' not in df.columns:
        raise ValueError("Error crítico: No existe la variable objetivo.")

    X = df[columnas]
    y = df['deserto']

    return X, y


# ===============================
# 5. División adaptable
# ===============================
def dividir_datos(X, y):
    test_size = 0.3 if len(X) > 20 else 0.2
    warnings.warn(f"Advertencia: Tamaño de dataset pequeño. Usando test_size={test_size}")
    return train_test_split(X, y, test_size=test_size, random_state=42)


# ===============================
# 6. Entrenamiento siempre que sea posible
# ===============================
def entrenar_modelo(X_train, y_train):
    modelo = RandomForestClassifier()
    modelo.fit(X_train, y_train)
    return modelo


# ===============================
# 7. Flujo principal parcial
# ===============================
def main_parcial():
    try:
        print("🔹 Cargando datos...")
        df = cargar_datos("data.xlsx")

        print("🔹 Detectando columnas disponibles...")
        columnas = obtener_columnas_validas(df)

        print("🔹 Limpiando datos automáticamente...")
        df = limpiar_datos(df, columnas)

        print("🔹 Definiendo variables...")
        X, y = definir_variables(df, columnas)

        print("🔹 Dividiendo datos...")
        X_train, X_test, y_train, y_test = dividir_datos(X, y)

        print("🔹 Entrenando modelo con variables disponibles...")
        modelo = entrenar_modelo(X_train, y_train)

        print("🔹 Predicción parcial completada.")
        y_prob = modelo.predict_proba(X_test)[:, 1]

        print("✅ Ejecución parcial completada con éxito.")

    except Exception as e:
        print(f"\n❌ {e}")


if __name__ == "__main__":
    main_parcial()
# Out:
# 🔹 Cargando datos...
# 🔹 Detectando columnas disponibles...
#
# ❌ Error crítico: Muy pocas variables para entrenar el modelo.
# C:\Users\Iris\AppData\Local\Temp\ipykernel_20084\2515637685.py:31: UserWarning: Advertencia: No se encontró la columna 'inasistencias'. Se omitirá.
#   warnings.warn(f"Advertencia: No se encontró la columna '{col}'. Se omitirá.")
# C:\Users\Iris\AppData\Local\Temp\ipykernel_20084\2515637685.py:31: UserWarning: Advertencia: No se encontró la columna 'promedio'. Se omitirá.
#   warnings.warn(f"Advertencia: No se encontró la columna '{col}'. Se omitirá.")
# C:\Users\Iris\AppData\Local\Temp\ipykernel_20084\2515637685.py:31: UserWarning: Advertencia: No se encontró la columna 'participacion'. Se omitirá.
#   warnings.warn(f"Advertencia: No se encontró la columna '{col}'. Se omitirá.")
# C:\Users\Iris\AppData\Local\Temp\ipykernel_20084\2515637685.py:31: UserWarning: Advertencia: No se encontró la columna 'apoyo_familiar'. Se omitirá.
# ...
